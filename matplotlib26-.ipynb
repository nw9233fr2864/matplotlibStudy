# %%
#26. Matplolib 텍스트 삽입하기
#27. Matplotlib 수학적 표현 사용하기 / raw string

# %%
#28. Matplotlib 그래프 스타일 설정하기
#plt.style.use / 미리 많들어 놓은 Matplotli 그래프 스토리

import matplotlib.pyplot as plt

print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#rc Params 사용하기

import matplotlib.pyplot as plt

plt.style.use('bmh')
plt.rcParams['figure.figsize'] = (6,3) #그래프 이미지의 크기
plt.rcParams['font.size'] = 12 #폰트의 크기
plt.rcParams['lines.linewidth'] = 5
plt.rcParams['lines.linestyle'] = '--'

plt.plot([1,2,3,4],[2,3,5,10])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['xtick.direction'] = 'inout'
plt.rcParams['ytick.direction'] = 'in'

plt.plot([1,2,3,4],[2,3,5,10])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['xtick.major.size'] = 7
plt.rcParams['ytick.major.size'] = 7
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.minor.visible'] = True

plt.plot([1,2,3,4],[2,3,5,10])

plt.show()

#etc.

# %%
#29 Matplotlib 이미지 저장하기
#savefig()
